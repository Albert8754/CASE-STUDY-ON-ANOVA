# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# firstly we imported different libraries to perform the case study

# %%
data = pd.read_csv("Sales_data_zone_wise.csv")

# %%
data.head()
# Out:
#        Month  Zone - A  Zone - B  Zone - C  Zone - D
# 0  Month - 1   1483525   1748451   1523308   2267260
# 1  Month - 2   1238428   1707421   2212113   1994341
# 2  Month - 3   1860771   2091194   1282374   1241600
# 3  Month - 4   1871571   1759617   2290580   2252681
# 4  Month - 5   1244922   1606010   1818334   1326062

# %%
data.shape
# Out:
# (29, 5)

# %%
data.isna().sum()
# Out:
# Month       0
# Zone - A    0
# Zone - B    0
# Zone - C    0
# Zone - D    0
# dtype: int64

# %% [markdown]
# we got our data is properly printed.there are 29 rows and 5 columns and no null values

# %% [markdown]
# # The mean sales generated by each zone.

# %%
data.mean()
# Out:
# Zone - A    1.540493e+06
# Zone - B    1.755560e+06
# Zone - C    1.772871e+06
# Zone - D    1.842927e+06
# dtype: float64

# %% [markdown]
# we found mean sales of each zone.we found that zone D have largest mean sales

# %% [markdown]
# # Total sales generated by all the zones for each month

# %%
plt.boxplot(data[['Zone - A','Zone - B','Zone - C','Zone - D']])
plt.show()

# %%
data.drop(['Month'],axis=1).sum()
# Out:
# Zone - A    44674301
# Zone - B    50911228
# Zone - C    51413260
# Zone - D    53444876
# dtype: int64

# %% [markdown]
# This is the total sum generated in differnt zones

# %%
data['Total']=data.sum(axis=1)
data
# Out:
#          Month  Zone - A  Zone - B  Zone - C  Zone - D    Total
# 0    Month - 1   1483525   1748451   1523308   2267260  7022544
# 1    Month - 2   1238428   1707421   2212113   1994341  7152303
# 2    Month - 3   1860771   2091194   1282374   1241600  6475939
# 3    Month - 4   1871571   1759617   2290580   2252681  8174449
# 4    Month - 5   1244922   1606010   1818334   1326062  5995328
# 5    Month - 6   1534390   1573128   1751825   2292044  7151387
# 6    Month - 7   1820196   1992031   1786826   1688055  7287108
# 7    Month - 8   1625696   1665534   2161754   2363315  7816299
# 8    Month - 9   1652644   1873402   1755290   1422059  6703395
# 9   Month - 10   1852450   1913059   1754314   1608387  7128210
# 10  Month - 11   2004480   1740365   1317869   1970069  7032783
# 11  Month - 12   1537539   1875658   1237722   1460165  6111084
# 12  Month - 13   1254939   1588473   1348629   1733383  5925424
# 13  Month - 14   1821799   1844081   1617376   1872259  7155515
# ...

# %% [markdown]
# WE have got sales generated by each zones in different month

# %%
plt.plot(data.Month,data.Total)
plt.xticks(rotation=90)
plt.xlabel('Month')
plt.ylabel('Total')
plt.show()

# %% [markdown]
# # Check whether all the zones generate the same amount of sales.

# %%
from scipy.stats import f_oneway
f_oneway(data['Zone - A'],data['Zone - B'],data['Zone - C'],data['Zone - D'])
# Out:
# F_onewayResult(statistic=5.672056106843581, pvalue=0.0011827601694503335)

# %% [markdown]
# Since p value obtained is less than .05 we can reject null hypothesis

# %% [markdown]
# the amount of sales in all the zones generated are different
